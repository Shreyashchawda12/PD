# %%
import pandas as pd

# %% [markdown]
# # PD Data

# %%
df1 = pd.read_excel("artifacts\VIL PD Alarm - Final (2).xlsx")

# %%
df1
# Out:
#       Sr.N                  Site ID             4G node name  New NSS ID  \
# 0        1                   SKWD01                  LSKWD01  IDMH107426
# 1        2                   PWNR01                  LPWNR01  IDMH100129
# 2        3                   AMVT69                  LAMVT69  IDMH100314
# 3        4                   GTNJ01                  4GTNJ01  IDMH100425
# 4        5                   PLAM01                  LPLAM01  IDMH101191
# ...    ...                      ...                      ...         ...
# 4403  4404                   KAGL12                  LKAGL12  INMHVF5679
# 4404  4405                   JLGN34                  4JLGN34  IDMH108758
# 4405  4406                   TKMB01                  LTKMB01  INMH406297
# 4406  4407                   LNVL38                  LLNVL38  INMH406493
# 4407  4408  LMGOD7405-GAGODE-VIOM-L  LMGOD7405-GAGODE-VIOM-L  INMHVF2393
#
#       4G node ID/OD DG/Non DG           Zone           IP ID  Global ID  ...  \
# ...

# %%
df1.shape
# Out:
# (4408, 180)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4408 entries, 0 to 4407
# Columns: 180 entries, Sr.N to Alarms.68
# dtypes: float64(156), int64(2), object(22)
# memory usage: 6.1+ MB

# %%
df1.columns
# Out:
# Index(['Sr.N', 'Site ID', '4G node name', 'New NSS ID', '4G node', 'ID/OD',
#        'DG/Non DG', 'Zone', 'IP ID', 'Global ID',
#        ...
#        '6-Mar USI', 'Alarms.64', '7-Mar USI', 'Alarms.65', '8-Mar USI',
#        'Alarms.66', '9-Mar USI', 'Alarms.67', '10-Mar USI', 'Alarms.68'],
#       dtype='object', length=180)

# %%
df2 = df1[["Site ID","Global ID","Site Name","Cluster","CE","RCA-1","RCA-2","Action Plan","Status","Closure Date/TAT","Jan-25","Feb-25","Mar-25","2025 PD Count"]]

# %%
df2.columns
# Out:
# Index(['Site ID', 'Global ID', 'Site Name', 'Cluster', 'CE', 'RCA-1', 'RCA-2',
#        'Action Plan', 'Status', 'Closure Date/TAT', 'Jan-25', 'Feb-25',
#        'Mar-25', '2025 PD Count'],
#       dtype='object')

# %%
df2[['Jan-25', 'Feb-25', 'Mar-25', '2025 PD Count']] = df2[['Jan-25', 'Feb-25', 'Mar-25', '2025 PD Count']].fillna(0)
# Out:
# C:\Users\shreyash12\AppData\Local\Temp\ipykernel_13992\636916117.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['Jan-25', 'Feb-25', 'Mar-25', '2025 PD Count']] = df2[['Jan-25', 'Feb-25', 'Mar-25', '2025 PD Count']].fillna(0)

# %%
df_Cluster = pd.pivot_table(df2, index = 'Cluster', values = ['Global ID'], aggfunc = 'count')

# %%
df_Cluster
# Out:
#                    Global ID  Status
# Cluster
# AHMEDNAGAR               245     245
# AKOLA                    440     440
# CH SAMBHAJI NAGAR        402     402
# GOA                      170     170
# KOLHAPUR                 459     459
# LATUR                    273     273
# NAGPUR                   507     507
# NASHIK                   410     410
# PUNE-1                   428     428
# PUNE-2                   390     390
# PUNE-3                   403     403
# SOLAPUR                  281     281

# %%
df2_filtered = df2[(df2['2025 PD Count'] != 0)]
dfc = pd.pivot_table(df2_filtered, index = 'Cluster',columns= 'Status', values = ['Global ID'], aggfunc = 'count')

# %%
dfc
# Out:
#                   Global ID
# Status               Closed  Open Site Switch Off To Be Update
# Cluster
# AHMEDNAGAR             32.0  48.0             NaN         18.0
# AKOLA                  25.0  66.0             NaN         85.0
# CH SAMBHAJI NAGAR      13.0  63.0             NaN         65.0
# GOA                     9.0  25.0             NaN         18.0
# KOLHAPUR                6.0  39.0             NaN        112.0
# LATUR                  41.0  74.0             NaN          1.0
# NAGPUR                 24.0  49.0             NaN        128.0
# NASHIK                 38.0  68.0             NaN         51.0
# PUNE-1                 20.0  61.0             NaN         98.0
# PUNE-2                 19.0   9.0             1.0        107.0
# PUNE-3                 20.0  33.0             NaN         99.0
# SOLAPUR                12.0  18.0             NaN         61.0
